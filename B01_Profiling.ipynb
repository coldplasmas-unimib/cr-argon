# %%
from Model import Levels, ElectronsTransitionsData, AtomsTransitionsData, PickAndSolve, UFloat, utilities

import pandas as pd
import cProfile


pas = PickAndSolve.PickAndSolve() # To init singletons

# %%
n_g = 2.687e25
T_g = 300

# %%
data = pd.read_csv('exports/SimulatedData.csv', index_col = False).to_dict('list')

data['density'] = [ UFloat.UFloat( n, s ) for n, s in zip( data['density_n'], data['density_s'] ) ]
data['label_idx'] = Levels.Levels().namesToIdxs( data['label'] )

# %%
# %prun pas.fit( data['density'], data['label_idx'], tol = 1e-9 )
# Out:
#          298438 function calls (298010 primitive calls) in 0.817 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       160    0.190    0.001    0.285    0.002 ElectronsTransitionsData.py:56(transMatrix)
#       160    0.170    0.001    0.271    0.002 AtomsTransitionsData.py:51(transMatrix)
#    152800    0.113    0.000    0.113    0.000 TransMatrix.py:19(__getitem__)
#     92480    0.074    0.000    0.074    0.000 TransMatrix.py:23(__setitem__)
#       160    0.024    0.000    0.057    0.000 _decomp_svd.py:13(svd)
#       160    0.022    0.000    0.023    0.000 lapack.py:982(_compute_lwork)
#      1331    0.019    0.000    0.019    0.000 {built-in method numpy.asanyarray}
#      1708    0.019    0.000    0.019    0.000 {built-in method numpy.asarray}
#      1442    0.012    0.000    0.012    0.000 {method 'reduce' of 'numpy.ufunc' objects}
# ...

# %%
# %prun pas.logChiSquared( data['density'], pas.getEquilibrium( n_g, 10**( -5 ), 2, T_g )[ data['label_idx'] ] )
# Out:
#          1805 function calls (1803 primitive calls) in 0.006 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.001    0.001    0.002    0.002 ElectronsTransitionsData.py:56(transMatrix)
#         1    0.001    0.001    0.002    0.002 AtomsTransitionsData.py:51(transMatrix)
#       955    0.001    0.000    0.001    0.000 TransMatrix.py:19(__getitem__)
#       578    0.001    0.000    0.001    0.000 TransMatrix.py:23(__setitem__)
#         1    0.000    0.000    0.000    0.000 _decomp_svd.py:13(svd)
#         1    0.000    0.000    0.006    0.006 {built-in method builtins.exec}
#         9    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#         7    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#         8    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
# ...

# %%
# %prun pas.getEquilibrium( n_g, 10**( -5 ), 2, T_g )
# Out:
#          1690 function calls (1688 primitive calls) in 0.008 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.002    0.002    0.003    0.003 ElectronsTransitionsData.py:56(transMatrix)
#         1    0.001    0.001    0.002    0.002 AtomsTransitionsData.py:51(transMatrix)
#       955    0.001    0.000    0.001    0.000 TransMatrix.py:19(__getitem__)
#       578    0.001    0.000    0.001    0.000 TransMatrix.py:23(__setitem__)
#         1    0.000    0.000    0.001    0.001 _decomp_svd.py:13(svd)
#         1    0.000    0.000    0.008    0.008 {built-in method builtins.exec}
#         1    0.000    0.000    0.008    0.008 PickAndSolve.py:18(getEquilibrium)
#         5    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     14/12    0.000    0.000    0.001    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
# ...

# %%
# %prun [ ( type( '1p2' ), type( 5 ) ) for i in range( 100000 ) ]
# Out:
#          2645 function calls in 0.057 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.051    0.051    0.055    0.055 <string>:1(<listcomp>)
#         1    0.002    0.002    0.057    0.057 <string>:1(<module>)
#       278    0.001    0.000    0.004    0.000 ipkernel.py:775(_clean_thread_parent_frames)
#       139    0.001    0.000    0.001    0.000 threading.py:1501(enumerate)
#       139    0.001    0.000    0.001    0.000 ipkernel.py:790(<setcomp>)
#       834    0.000    0.000    0.000    0.000 threading.py:1168(ident)
#         1    0.000    0.000    0.057    0.057 {built-in method builtins.exec}
#       556    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#       278    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#       278    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
# ...

# %%
# %prun [ ( isinstance( '1p2', str ), isinstance( 5, str ) ) for i in range( 100000 ) ]
# Out:
#          202790 function calls in 0.210 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.155    0.155    0.165    0.165 <string>:1(<module>)
#         1    0.026    0.026    0.031    0.031 {method 'execute' of 'sqlite3.Connection' objects}
#    200285    0.017    0.000    0.017    0.000 {built-in method builtins.isinstance}
#         2    0.005    0.002    0.008    0.004 {method '__exit__' of 'sqlite3.Connection' objects}
#         1    0.003    0.003    0.003    0.003 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.002    0.001    0.002    0.001 threading.py:299(__enter__)
#         1    0.001    0.001    0.040    0.040 history.py:1008(_writeout_input_cache)
#       278    0.001    0.000    0.002    0.000 ipkernel.py:775(_clean_thread_parent_frames)
#       139    0.001    0.000    0.001    0.000 threading.py:1535(enumerate)
# ...
